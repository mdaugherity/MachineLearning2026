# %% [markdown]
# <a href="https://colab.research.google.com/github/mdaugherity/MachineLearning2026/blob/main/class/HW4_Digits_Throwdown.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # HW4 - Digits Throwdown
#
# Name: **YOUR NAME HERE**
# Class: PHYS453 - Machine Learning
# Date: Spring 2026

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_digits

# %% [markdown]
# In this assignment you will check how well our classifiers work on hand-written numbers.  Use my digits dataset tutorial to help you get started.
#
# You will evaluate 3 different classifiers on the digits dataset.  You have some specific tasks for each one.
#
# **WARNING**: As I showed in the digits tutorial, **do not use StandardScaler** on this dataset.  I'll scale it for you below.

# %% [markdown]
# # Load Data

# %%
X,y = load_digits(return_X_y=True)

# %%
X_scaled = X/16.0  # Data are already preprocessed, this is all we need

# %% [markdown]
# # Test/Train Split

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, stratify=y, random_state=0) # Using X_scaled, also stratify ensures an equal ratio of each target
print("Data:  ",X.shape,y.shape)
print("Train: ",X_train.shape, y_train.shape)
print("Test:  ",X_test.shape,y_test.shape)
# Out:
# Data:   (1797, 64) (1797,)
# Train:  (1347, 64) (1347,)
# Test:   (450, 64) (450,)

# %% [markdown]
# You may only use the `fit` function on X_train and y_train. If you try to fit the test data you will be immediately expelled.

# %% [markdown]
# # Problem 1 - Gaussian Naive Bayes
#
#
# * Fit the training set, then find the score and confusion matrix for the test set
# * Use the `theta_` attribute to plot the average pixels for every number 0-9

# %% [markdown]
# # Problem 2 - Nearest Neighbors
# * Find the optimal value of k. Justify your answer.
# * Fit the training set using your optimal k and produce a classification report on the test set
# * Show the 5 nearest neighbors to the first sample in the test set `X_test[0]`
# * Show the 5 nearest neighbors to any one of the miss-classified points in the test set

# %% [markdown]
# # Problem 3 - Decision Tree
# * Find the optimal value of max_depth.  Justify your answer.
# * Use the `feature_importances_` attribute and make a plot showing the most important pixels

# %% [markdown]
# # Problem 4 - Lasso L1
# One of the more difficult concepts is the difference between L1 and L2 regularization.  Let's explore L1 with LassoCV.
#
# https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LassoCV.html#sklearn.linear_model.LassoCV
#
# * Train a LassoCV classifier
# * Print the value of alpha determined by the automatic CV search
# * Look at the weights stored in **clf.coef_**.  How many of the 64 pixels were set to 0?  Make a plot showing them.

# %% [markdown]
# # Problem 5 - Final Evaluation
# After completing the first three tasks, explain which of these classifiers is **best** for the digits dataset.  Run any more tests you need.  Justify your answer.
