# %% [markdown]
# <a href="https://colab.research.google.com/github/mdaugherity/MachineLearning2026/blob/main/class/HW1_Mystery_Classifiers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.inspection import DecisionBoundaryDisplay

from sklearn.svm import LinearSVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC

# %% [markdown]
# #HW 1 - Using Mystery Classifiers
#
# **Pre-reqs:**  *Tutorial 4 - Using Classifiers*
#
# Show that you understand how classifiers are used.  You should copy **some** of the code from Tutorial 4, but only take what you need.

# %% [markdown]
# # Problem 0 - The Five Steps
#
# Work through the standard steps and fill in the missing pieces

# %% [markdown]
# **Getting Data:**  Let's use the *make_moons* command to generate some fake data with 2 features and 2 classes

# %%
X,y = datasets.make_moons(n_samples=100, random_state=0, noise=0.5)

# %% [markdown]
# **Preprocessing**: Do the standard test/train split with random_state=0

# %% [markdown]
# **Training**: We will use a simple linear classifier.  Fit it to the CORRECT data.

# %%
clf = LinearSVC()

# %% [markdown]
# **Evaluating:** Show the test and train scores

# %% [markdown]
# **Predicting:** Predict the target for a new point with features [0, 0].
#
# Remember that X is always a 2D array (even for predicting just one sample)

# %% [markdown]
# # Problem 1 - Moons
#
# Answer questions from your classifier in problem 0

# %% [markdown]
# a) Does this classifier underfit, overfit, or fit well?  Justify your answer

# %% [markdown]
# b) Plot a decision boundary showing the train and test points

# %% [markdown]
# c) Print out the features of every point in test that your classifier got wrong

# %% [markdown]
# d) Is target 0 the moon above the line or below line? Prove your answer by predicting one or more points and showing them on a new scatterplot

# %% [markdown]
# # Problem 2 - Blobs
#
# Use this dataset and classifier

# %%
X,y = datasets.make_blobs(n_samples=100, random_state=0, centers=[[-1,0],[1,0]], cluster_std=2)
clf = DecisionTreeClassifier(max_depth=6)

# %% [markdown]
# a) Do the standard test/train split and plot the data.  Make the test and train points look different.

# %% [markdown]
# b) Train the classifier and plot the decision boundary.

# %% [markdown]
# c) Does this classifier underfit, overfit, or fit well?  Justify your answer

# %% [markdown]
# # Problem 3 - Tuning
# You may get used to plotting decision boundaries to see how well your classifier is working.  Unfortunately, some problems are virtually impossible to visualize this way.
#
# Here's a dataset with 20 features and 2 classes

# %%
X,y = datasets.make_classification(random_state=0)
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)
X.shape
# Out:
# (100, 20)

# %%
clf = SVC(kernel="poly",degree=0)

# %% [markdown]
# You need to tune the options ("hyperparameters") of a classifier to find the best one.  Try changing the degree to 0, 1, or 2.  Which one gives the best balance between under-fitting and over-fitting?
