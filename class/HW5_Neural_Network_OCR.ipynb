# %% [markdown]
# <a href="https://colab.research.google.com/github/mdaugherity/MachineLearning2026/blob/main/class/HW5_Neural_Network_OCR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Name: Dr D
# Class: PHYS453
#
#
# # HW5 - Neural Network OCR
# Clever and/or funny title goes here.
#
# # Tasks
# The best for last: for our final homework assignment you will train a neural network to recognize your own handwriting.
# 1. Train an MLPClassifier on the digits dataset and find the expected accuracy (from test/train split). Discuss how the neural network performs relative to the other classifiers from HW4?
# 1. Load in a scanned image of your handwriting for the digits 0-9
# 1. Demonstrate that your MLP can classify them with at least 50% accuracy, and discuss if your prediction accuracy is what you expected
#
# # Notes
# * No, I will **not** tell you how to read image files in python.  The greatest skill you can have is learning how to google, read documentation, and make code work.  This is vital to practice before tackling our final projects.
# * You can use my scanned image if you want, but you are not required to.
# * Remember my note about how not to scale digits and what to do instead.
# * Both the digits dataset and your handwriting must be scaled the same way!  This will require work on your part.
