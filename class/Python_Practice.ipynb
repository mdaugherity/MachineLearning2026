# %% [markdown]
# <a href="https://colab.research.google.com/github/mdaugherity/MachineLearning2026/blob/main/class/Python_Practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Dr. Daugherity, ACU PHYS 453

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import datasets

# %% [markdown]
# # Python Practice
# Before these machines can start learning, we need to practice using numpy and matplotlib.
# **See Tutorials 1 through 3 and the cheat sheets on github for examples .**

# %% [markdown]
# # Load Data
# Let's load in some [real exercise data](https://scikit-learn.org/stable/datasets/toy_dataset.html#linnerrud-dataset) to play with.
#
# *NOTE: I'm going to download and package up the data for us. DO NOT CHANGE ANYTHING HERE. I'll explain what these commands do later.*

# %%
# Don't change this
data_bunch = datasets.load_linnerud()  # grab the data "bunch" from sklearn
data = np.hstack((data_bunch.data, data_bunch.target))  # combine everything into one array
columns = data_bunch.feature_names + data_bunch.target_names
print('The columns are: ', columns)
chins = data[:,0]
# Out:
# The columns are:  ['Chins', 'Situps', 'Jumps', 'Weight', 'Waist', 'Pulse']

# %% [markdown]
# We have exercise data on 20 different people.
# * `chins` is a 1D array with a list of how many chin-ups each person can do.
# * `data` is a 2D array, each row is a person, each column is the value named in `columns`
#
# These people don't have names, so we will refer to them as person 0 to person 19

# %% [markdown]
# # Problem 1 - 1D Array

# %%
# Find the total and average number of chins

# %%
# For each person who did 15 or more chins, print the person's index and their chins

# %%
# What is the smallest number of chins?  Who was it?  (Hint: use argmin)

# %%
# Plot person number vs chins.  Label everything

# %%
# Make a nice histogram of chins.  Label everything.

# %% [markdown]
# # Problem 2 - 2D Array

# %%
# Print a table with column numbers and names

# %%
# Print the data on person 8

# %%
# What does person 4 weigh?

# %%
# Print number of jump for everyone with pulse <55

# %%
# Who did the most situps?

# %%
# For each person, calculate the sum of chins + situps + jumps (Hint: the sum function has an axis argument)

# %%
# Print out all the information on the heaviest and lightest people.

# %%
# Make a plot of weight vs waist size
